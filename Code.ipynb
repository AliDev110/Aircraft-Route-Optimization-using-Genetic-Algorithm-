# %% [markdown]
# # AI Lab Project
# #### Ali Raza - 20I-0782
# #### Haris Shahid - 20I-0663

# %%
# %pip install Flask
# Out:
# Requirement already satisfied: Flask in e:\python\lib\site-packages (3.0.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: Werkzeug>=3.0.0 in e:\python\lib\site-packages (from Flask) (3.0.0)
# Requirement already satisfied: Jinja2>=3.1.2 in e:\python\lib\site-packages (from Flask) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in e:\python\lib\site-packages (from Flask) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in e:\python\lib\site-packages (from Flask) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in e:\python\lib\site-packages (from Flask) (1.7.0)
# Requirement already satisfied: colorama in c:\users\pc\appdata\roaming\python\python311\site-packages (from click>=8.1.3->Flask) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\python\lib\site-packages (from Jinja2>=3.1.2->Flask) (2.1.3)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from math import sqrt
import random

# %% [markdown]
# ### Reading Datasets

# %%
aircraftData = pd.read_csv("aircraftDataset.csv")
aircraftData = pd.DataFrame(aircraftData)


airportData = pd.read_csv("airportDataset.csv")
airportData = pd.DataFrame(airportData)


weatherData = pd.read_csv("weatherDataset.csv")
weatherData = pd.DataFrame(weatherData)

# %%
aircraftData.head(5)

#=========================Data Interpretation==============================

# Aircraft Type	                    | Max Range (In KM)                       | Cruise Speed (Kmph)     | Fuel Consumption at Cruise (litres per hr) 
# Uniquely identifies each aircraft | Max distance possible without refueling |  Speed at cruise height | Fuel consumed per hr       

# ICAO CODES
# Aircraft is available at this airport

#aircraftData['Aircraft Type'].where(aircraftData['ICAO CODES'] == 'ISLA')
# Out:
#   Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0    Aircraft 1  3524.704974    440.407155                 1084.211636
# 1    Aircraft 2  7463.252518    474.475130                  494.213927
# 2    Aircraft 3  7810.298939    463.793756                  402.758677
# 3    Aircraft 4  1442.066536    188.000000                  788.008426
# 4    Aircraft 5  6261.240012    411.286311                  993.237674
#
#   ICAO CODES
# 0       MULT
# 1       KARA
# 2       PESH
# 3       SIAL
# 4       SUKK

# %%
#=========================Data Interpretation==============================

# Date            | Wind Speed | Wind Direction     | City 
# Departure date  | In kmph    | In degrees (0-360) | relavent city

# %%
airportData.head(5)

#=========================Data Interpretation==============================

# ICAO                        | Latitude (In km)                                        | Longitude                                              | City 
# Uniquely identifies airport | Latitude distance from airport to city in city column   | Longitude distance from airport to city in city column | destination city
# Out:
#   ICAO Code  Latitude  Longitude      City
# 0      ISLA      2580       2886  Peshawar
# 1      ISLA      3785       2691   Karachi
# 2      ISLA      2225        264    Lahore
# 3      ISLA       106       2616    Quetta
# 4      ISLA      1799       2184    Multan

# %% [markdown]
# ### Preprocessing

# %%
# Remove rows where 'fuel consumption', 'cruise speed', and 'max range' are NaN
aircraftData = aircraftData.dropna(subset=['Fuel Consumption at Cruise', 'Cruise Speed', 'Max Range'])

#Bring wind direction in range(0,360) degrees 
weatherData['Wind Direction'] = weatherData['Wind Direction'] % 360
weatherData.head(5)
# Out:
#          Date  Wind Speed  Wind Direction        City
# 0  2007-01-01   24.316468      255.233176      Multan
# 1  2007-01-01   28.748364      104.971560   Islamabad
# 2  2007-01-01   27.188154      170.915093  Gujranwala
# 3  2007-01-01    8.418233      268.304630     Karachi
# 4  2007-01-01    1.945127      288.329295     Sialkot

# %% [markdown]
# ### Supporting Functions

# %%
def euclidean_distance(coords):
    
    lat1, lon1 = coords 
    distance = sqrt((lat1)**2+(lon1)**2)

    return distance

# %% [markdown]
# ### Fitness Function

# %%
#Smaller fitness is better

def fitness(route,date,aircraftData=aircraftData,weatherData=weatherData):

    fitness = 0

    fuel_weightage = 0.7
    time_weightage = 0.3

    #Weather wind speed categories (see report for details on chosen ranges)
    max_safe = 15
    max_acceptable = 30
    max_cautionary = 45
    max_unsafe = 60
    #Else impossible/ too dangerous 

    src_weather_weight = 1
    dest_weather_weight = 1

    


    for i in range(len(route)-1):

        curr_src = route[i]
        curr_dest = route[i+1]

        print("\n\n==================================",curr_src," TO ",curr_dest,"==================================\n\n")

        #--------------------------------------------------------------Aircraft fitness---------------------------------------------------

        #Distance between current airport and next airport in the route
        distance = euclidean_distance(airportData.loc[(airportData['ICAO Code'] == curr_src) & (airportData['City'].str.upper().str[:4] == curr_dest), ['Latitude', 'Longitude']].values.flatten())
        print("Distance of journey",distance, "KM")

        #Eligible aircrafts
        aircrafts = aircraftData.loc[(aircraftData['ICAO CODES'] == curr_src) & (aircraftData['Max Range'] >= distance),'Aircraft Type'].values

        print("Eligible aircrafts:\n",aircrafts)
        print(len(aircrafts),"aircrafts available at airport ",curr_src,"\n")

        #Returing -1 means the route is unusable
        if(len(aircrafts) == 0):
            return -1

        #Best fuel efficiency
        min_consumption = float(aircraftData.loc[aircraftData['Aircraft Type'].isin(aircrafts.flatten()), 'Fuel Consumption at Cruise'].min())

        #print(min_consumption)
        best_aircraft = aircraftData.loc[aircraftData['Fuel Consumption at Cruise'] == min_consumption].reset_index(drop=True)
        print("\nBest aircraft for journey :\n", best_aircraft)

        #Time taken in hrs
        time = float(distance / (best_aircraft['Cruise Speed'].iloc[0]))
        print("\nDuration of flight:", time, "Hrs")
        print("\nFuel consumption:",min_consumption*time, "Litres")

        #Aircraft fitness (Scaling time in hrs by 100) | (min_consumption is in litres per hr)
        aircraft_fitness = ((time*100)*time_weightage) + ((min_consumption*time)*fuel_weightage)

        #--------------------------------------------------------------Weather fitness---------------------------------------------------
        #source weather
        src_wind_speed = float(weatherData.loc[(weatherData['City'].str.upper().str[:4] == curr_src) & (weatherData['Date'] == date),'Wind Speed'].iloc[0])
        print("\nWind speed in (SOURCE)", curr_src, ":",src_wind_speed)

        #destination weather
        dest_wind_speed = float(weatherData.loc[(weatherData['City'].str.upper().str[:4] == curr_dest) & (weatherData['Date'] == date),'Wind Speed'].iloc[0])
        print("\nWind speed in (DESTINATION)", curr_dest, ":",dest_wind_speed)

        #Source weather effects
        if(np.isnan(src_weather_weight)): #If no data is present then must be cautious hence the weight is same as that of cautionary category 
            src_weather_weight = 1.5
        elif(src_wind_speed <= max_safe):
            src_weather_weight = 1
        elif(src_wind_speed <= max_acceptable):
            src_weather_weight = 1.25 
        elif(src_wind_speed <= max_cautionary | np.isnan(src_weather_weight)):
            src_weather_weight = 1.5
        elif(src_wind_speed <= max_unsafe):
            src_weather_weight = 1.75
        elif(src_wind_speed > max_unsafe):
            #Impossible
            return -1 #Returing -1 means the route is unusable
        
        #Destination weather effects
        if(np.isnan(dest_weather_weight)): #If no data is present then must be cautious hence the weight is same as that of cautionary category 
            dest_weather_weight = 1.5
        elif(dest_wind_speed <= max_safe):
            dest_weather_weight = 1
        elif(dest_wind_speed <= max_acceptable):
            dest_weather_weight = 1.25 
        elif(dest_wind_speed <= max_cautionary):
            dest_weather_weight = 1.5
        elif(dest_wind_speed <= max_unsafe):
            dest_weather_weight = 1.75
        elif(dest_wind_speed > max_unsafe):
            #Impossible
            return -1 #Returing -1 means the route is unusable

        local_fitness = aircraft_fitness*src_weather_weight*dest_weather_weight
        fitness += local_fitness
        print("\n====> FITNESS =",local_fitness,"<====")

    return fitness

# %% [markdown]
# ### Core Functions

# %%
def init_pop(src, dest, population_size):
    
    # Initialize 50 possible routes randomly with random lengths
    population = []

    for _ in range(population_size):
        # Create a random route length between 2 and the total number of airports
        route_length = random.randint(2, len(airportData['ICAO Code'].unique()))
        
        # Create a random route with the specified length, excluding src and dest
        route = random.sample([city for city in airportData['ICAO Code'].unique() if city not in [src, dest]], route_length - 2)
        route = [src] + route + [dest]
        population.append(route)

    return population

def selection(population, fitness_values):

    # Select the best 2 routes based on fitness (lower fitness is better)
    sorted_indices = np.argsort(fitness_values)
    selected_routes = [population[i] for i in sorted_indices[:2]]

    return selected_routes


def crossover(parent1, parent2, src, dest):

    # Randomly select a crossover point between 1 and the minimum length of the parents
    crossover_point = random.randint(1, min(len(parent1), len(parent2)) - 1)
    
    # create children
    child1 = parent1[1:crossover_point] + [city for city in parent2 if city not in parent1[1:crossover_point]]
    child2 = parent2[1:crossover_point] + [city for city in parent1 if city not in parent2[1:crossover_point]]
    
    # Remove all instances of src and dest from the children except for the first and last indices
    child1 = [src] + [city for city in child1[1:-1] if city != src] + [dest]
    child1 = [city for city in child1[0:-1] if city != dest] + [dest]

    child2 = [src] + [city for city in child1[1:-1] if city != src] + [dest]
    child2 = [city for city in child1[0:-1] if city != dest] + [dest]
    return child1, child2



def mutation(route):

    # Randomly decide whether to:
    # 1. Remove a connection
    # 2. Add a new connection (least likely)
    # 3. Change a random existing connection

    mutation_type = random.choice([1,2,3])

    if mutation_type == 1 and len(route) > 3:
        # Remove a connection
        remove_index = random.randint(1, len(route) - 2)
        route.pop(remove_index)
    elif mutation_type == 2:
        # Add a new connection
        new_city = random.choice([city for city in airportData['ICAO Code'].unique() if city not in route])
        insert_index = random.randint(1, len(route) - 1)
        route.insert(insert_index, new_city)
    elif mutation_type == 3 and len(route) > 2:
        # Change a random existing connection
        change_index = random.randint(1, len(route) - 2)
        new_city = random.choice([city for city in airportData['ICAO Code'].unique() if city != route[change_index]])
        route[change_index] = new_city

    return route


def replace(population, children, fitness_values):

    # Replace worst 2 from the population with the new children
    sorted_indices = np.argsort(fitness_values)
    population[sorted_indices[-2]] = children[0]
    population[sorted_indices[-1]] = children[1]

    return population

# %% [markdown]
# ### Driver Function

# %%
import random

def geneticAlgo(src, dest, date):

    population_size = 20
    generations = 1

    # Initialize population
    population = init_pop(src,dest,population_size)
    print(population)
        
    for generation in range(generations):
        
        # Evaluate fitness of each route in the population
        fitness_values = [fitness(route, date) for route in population]
        #print(fitness_values)

        # Select the best routes
        selected_routes = selection(population, fitness_values)
        #print(selected_routes)

        # Perform crossover to create children
        children = []
        for i in range(0, len(selected_routes), 2):
            child1, child2 = crossover(selected_routes[i], selected_routes[i + 1], src, dest)
            children.extend([child1, child2])
        
        print(children)

        # Perform mutation on children
        mutated_children = [mutation(child) for child in children]

        print(mutated_children)

        # Replace the worst routes in the population with the new children
        population = replace(population, mutated_children, fitness_values)

        # Print the best fitness in each generation
        best_fitness = min(fitness_values)
        print(f"Generation {generation + 1}, Best Fitness: {best_fitness}")

    # Select the best route after all generations
    best_route_index = np.argmin(fitness_values)
    optimal_route = population[best_route_index]

    # Extract the next best 5 routes
    sorted_routes_indices = np.argsort(fitness_values)
    alt_routes_indices = sorted_routes_indices[1:6]
    alt_routes = [population[i] for i in alt_routes_indices]

    return optimal_route, alt_routes

# %% [markdown]
# ### Visualization and Frontend

# %%
from flask import Flask, render_template, request

app = Flask(__name__)


@app.route('/', methods=['GET', 'POST'])
def optimizeRoute():
    if request.method == 'POST':
        try:
            #Extract user input from webpage
            source = request.form['source']
            destination = request.form['destination']
            date = request.form['date']
            
            #Call genetic algorithm function
            result, alt_routes = geneticAlgo(source,destination,date)
            alt1 = alt_routes[0]
            alt2 = alt_routes[1]
            alt3 = alt_routes[2]
            alt4 = alt_routes[3]
            alt5 = alt_routes[4]

            #Render page to display optimal and alternative routes
            return render_template('front.html', result=result, alt1=alt1, alt2=alt2, alt3=alt3, alt4=alt4, alt5=alt5)
        except ValueError:
            error_message = "Invalid input. Please enter valid values for source, destination, and date."
            return render_template('front.html', error_message=error_message)
    else:
        return render_template('front.html')


if __name__ == '__main__':
    try:
        app.run(debug=True, use_reloader=False)
    except Exception as e:
        print(f"An error occurred: {str(e)}")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [06/Dec/2023 14:28:14] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Dec/2023 14:28:15] "GET /static/peakpx.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Dec/2023 14:28:15] "GET /favicon.ico HTTP/1.1" 404 -
# [['ISLA', 'MULT', 'KARA'], ['ISLA', 'GUJR', 'GWAD', 'MULT', 'FAIS', 'KARA'], ['ISLA', 'RAWA', 'GWAD', 'QUET', 'SUKK', 'MULT', 'PESH', 'GUJR', 'KARA'], ['ISLA', 'QUET', 'MULT', 'FAIS', 'LAHO', 'PESH', 'KARA'], ['ISLA', 'GUJR', 'GWAD', 'MULT', 'PESH', 'LAHO', 'RAWA', 'SUKK', 'QUET', 'FAIS', 'SIAL', 'KARA'], ['ISLA', 'RAWA', 'SIAL', 'QUET', 'SUKK', 'MULT', 'GWAD', 'PESH', 'LAHO', 'KARA'], ['ISLA', 'PESH', 'SUKK', 'MULT', 'KARA'], ['ISLA', 'MULT', 'RAWA', 'FAIS', 'QUET', 'LAHO', 'GUJR', 'SUKK', 'PESH', 'KARA'], ['ISLA', 'SUKK', 'RAWA', 'SIAL', 'LAHO', 'QUET', 'PESH', 'GWAD', 'MULT', 'FAIS', 'KARA'], ['ISLA', 'FAIS', 'MULT', 'RAWA', 'GWAD', 'GUJR', 'LAHO', 'KARA'], ['ISLA', 'FAIS', 'QUET', 'SUKK', 'GUJR', 'KARA'], ['ISLA', 'SIAL', 'MULT', 'SUKK', 'FAIS', 'PESH', 'LAHO', 'KARA'], ['ISLA', 'MULT', 'KARA'], ['ISLA', 'GUJR', 'FAIS', 'MULT', 'SUKK', 'SIAL', 'RAWA', 'LAHO', 'KARA'], ['ISLA', 'SIAL', 'MULT', 'LAHO', 'SUKK', 'GUJR', 'GWAD', 'PESH', 'FAIS', 'KARA'], ['ISLA', 'LAHO', 'MULT', 'RAWA', 'SUKK', 'SIAL', 'QUET', 'GWAD', 'PESH', 'GUJR', 'KARA'], ['ISLA', 'MULT', 'PESH', 'SUKK', 'QUET', 'GWAD', 'KARA'], ['ISLA', 'QUET', 'SIAL', 'RAWA', 'MULT', 'LAHO', 'GUJR', 'FAIS', 'KARA'], ['ISLA', 'QUET', 'GUJR', 'KARA'], ['ISLA', 'SUKK', 'FAIS', 'SIAL', 'RAWA', 'KARA']]
#
#
# ================================== ISLA  TO  MULT ==================================
#
#
# Distance of journey 2829.533000337688 KM
# Eligible aircrafts:
#  ['Aircraft 14' 'Aircraft 35' 'Aircraft 62' 'Aircraft 69' 'Aircraft 95'
#  'Aircraft 120' 'Aircraft 127' 'Aircraft 138' 'Aircraft 143'
#  'Aircraft 195' 'Aircraft 223' 'Aircraft 234' 'Aircraft 258'
#  'Aircraft 262' 'Aircraft 264' 'Aircraft 284' 'Aircraft 287'
#  'Aircraft 344' 'Aircraft 346' 'Aircraft 365' 'Aircraft 395'
#  'Aircraft 400' 'Aircraft 410' 'Aircraft 412' 'Aircraft 421'
#  'Aircraft 462' 'Aircraft 468' 'Aircraft 470' 'Aircraft 503'
#  'Aircraft 505' 'Aircraft 507' 'Aircraft 511' 'Aircraft 513'
#  'Aircraft 516' 'Aircraft 517' 'Aircraft 520' 'Aircraft 530'
#  'Aircraft 532' 'Aircraft 565' 'Aircraft 584' 'Aircraft 601'
#  'Aircraft 606' 'Aircraft 610' 'Aircraft 640' 'Aircraft 654'
#  'Aircraft 667']
# 46 aircrafts available at airport  ISLA
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 344  4379.380871    480.757355                    103.3628
#
#   ICAO CODES
# 0       ISLA
#
# Duration of flight: 5.885574026454359 Hrs
#
# Fuel consumption: 608.3494095092861 Litres
#
# Wind speed in (SOURCE) ISLA : 28.74836369922879
#
# Wind speed in (DESTINATION) MULT : 24.31646750351273
#
# ====> FITNESS = 941.2684491408298 <====
#
#
# ================================== MULT  TO  KARA ==================================
#
#
# Distance of journey 3696.8295876331654 KM
# Eligible aircrafts:
#  ['Aircraft 27' 'Aircraft 37' 'Aircraft 47' 'Aircraft 48' 'Aircraft 57'
#  'Aircraft 81' 'Aircraft 90' 'Aircraft 114' 'Aircraft 123' 'Aircraft 160'
#  'Aircraft 203' 'Aircraft 208' 'Aircraft 210' 'Aircraft 229'
#  'Aircraft 323' 'Aircraft 339' 'Aircraft 397' 'Aircraft 454'
#  'Aircraft 474' 'Aircraft 488' 'Aircraft 574' 'Aircraft 632'
#  'Aircraft 634' 'Aircraft 644' 'Aircraft 656' 'Aircraft 678'
#  'Aircraft 685']
# 27 aircrafts available at airport  MULT
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 339  6709.734391         188.0                  132.573579
#
#   ICAO CODES
# 0       MULT
#
# Duration of flight: 19.663987168261517 Hrs
#
# Fuel consumption: 2606.9251558444407 Litres
#
# Wind speed in (SOURCE) MULT : 24.31646750351273
#
# Wind speed in (DESTINATION) KARA : 8.418232851835846
#
# ====> FITNESS = 3018.459030173692 <====
#
#
# ================================== ISLA  TO  GUJR ==================================
#
#
# Distance of journey 355.99578649191903 KM
# Eligible aircrafts:
#  ['Aircraft 14' 'Aircraft 35' 'Aircraft 62' 'Aircraft 69' 'Aircraft 95'
#  'Aircraft 120' 'Aircraft 127' 'Aircraft 138' 'Aircraft 143'
#  'Aircraft 195' 'Aircraft 223' 'Aircraft 234' 'Aircraft 245'
#  'Aircraft 258' 'Aircraft 262' 'Aircraft 264' 'Aircraft 284'
#  'Aircraft 287' 'Aircraft 313' 'Aircraft 344' 'Aircraft 346'
#  'Aircraft 365' 'Aircraft 395' 'Aircraft 400' 'Aircraft 410'
#  'Aircraft 412' 'Aircraft 421' 'Aircraft 462' 'Aircraft 468'
#  'Aircraft 470' 'Aircraft 479' 'Aircraft 503' 'Aircraft 505'
#  'Aircraft 507' 'Aircraft 511' 'Aircraft 513' 'Aircraft 514'
#  'Aircraft 516' 'Aircraft 517' 'Aircraft 520' 'Aircraft 530'
#  'Aircraft 532' 'Aircraft 565' 'Aircraft 568' 'Aircraft 572'
#  'Aircraft 584' 'Aircraft 601' 'Aircraft 606' 'Aircraft 610'
#  'Aircraft 618' 'Aircraft 635' 'Aircraft 640' 'Aircraft 654'
#  'Aircraft 658' 'Aircraft 667' 'Aircraft 686']
# 56 aircrafts available at airport  ISLA
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 344  4379.380871    480.757355                    103.3628
#
#   ICAO CODES
# 0       ISLA
#
# Duration of flight: 0.7404895275135422 Hrs
#
# Fuel consumption: 76.53907074923902 Litres
#
# Wind speed in (SOURCE) ISLA : 28.74836369922879
#
# Wind speed in (DESTINATION) GUJR : 27.1881540287728
#
# ====> FITNESS = 118.42505523417745 <====
#
#
# ================================== GUJR  TO  GWAD ==================================
#
#
# Distance of journey 2891.0565542721574 KM
# Eligible aircrafts:
#  ['Aircraft 6' 'Aircraft 23' 'Aircraft 33' 'Aircraft 36' 'Aircraft 44'
#  'Aircraft 59' 'Aircraft 80' 'Aircraft 91' 'Aircraft 96' 'Aircraft 116'
#  'Aircraft 117' 'Aircraft 125' 'Aircraft 133' 'Aircraft 135'
#  'Aircraft 140' 'Aircraft 172' 'Aircraft 174' 'Aircraft 191'
#  'Aircraft 194' 'Aircraft 202' 'Aircraft 211' 'Aircraft 237'
#  'Aircraft 259' 'Aircraft 267' 'Aircraft 268' 'Aircraft 269'
#  'Aircraft 276' 'Aircraft 293' 'Aircraft 308' 'Aircraft 350'
#  'Aircraft 368' 'Aircraft 381' 'Aircraft 385' 'Aircraft 411'
#  'Aircraft 417' 'Aircraft 433' 'Aircraft 450' 'Aircraft 475'
#  'Aircraft 524' 'Aircraft 526' 'Aircraft 545' 'Aircraft 558'
#  'Aircraft 571' 'Aircraft 573' 'Aircraft 575' 'Aircraft 578'
#  'Aircraft 629' 'Aircraft 646' 'Aircraft 655' 'Aircraft 666'
#  'Aircraft 681']
# 51 aircrafts available at airport  GUJR
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0    Aircraft 6  4335.214703    409.685328                  117.576422
#
#   ICAO CODES
# 0       GUJR
#
# Duration of flight: 7.056773479504457 Hrs
#
# Fuel consumption: 829.7101783766226 Litres
#
# Wind speed in (SOURCE) GUJR : 27.1881540287728
#
# Wind speed in (DESTINATION) GWAD : 18.95246078940032
#
# ====> FITNESS = 1238.2817644512024 <====
#
#
# ================================== GWAD  TO  MULT ==================================
#
#
# Distance of journey 1943.988940297758 KM
# Eligible aircrafts:
#  ['Aircraft 10' 'Aircraft 25' 'Aircraft 40' 'Aircraft 45' 'Aircraft 53'
#  'Aircraft 55' 'Aircraft 92' 'Aircraft 119' 'Aircraft 124' 'Aircraft 139'
#  'Aircraft 162' 'Aircraft 163' 'Aircraft 169' 'Aircraft 188'
#  'Aircraft 216' 'Aircraft 233' 'Aircraft 240' 'Aircraft 282'
#  'Aircraft 297' 'Aircraft 302' 'Aircraft 316' 'Aircraft 331'
#  'Aircraft 351' 'Aircraft 373' 'Aircraft 384' 'Aircraft 390'
#  'Aircraft 409' 'Aircraft 413' 'Aircraft 472' 'Aircraft 483'
#  'Aircraft 494' 'Aircraft 498' 'Aircraft 528' 'Aircraft 534'
#  'Aircraft 535' 'Aircraft 564' 'Aircraft 586' 'Aircraft 614'
#  'Aircraft 615' 'Aircraft 622' 'Aircraft 628' 'Aircraft 645'
#  'Aircraft 650' 'Aircraft 664' 'Aircraft 668' 'Aircraft 674'
#  'Aircraft 680' 'Aircraft 687' 'Aircraft 699']
# 49 aircrafts available at airport  GWAD
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 384  3669.018443    535.323871                  134.901614
#
#   ICAO CODES
# 0       GWAD
#
# Duration of flight: 3.631425841401726 Hrs
#
# Fuel consumption: 489.88520643054886 Litres
#
# Wind speed in (SOURCE) GWAD : 18.95246078940032
#
# Wind speed in (DESTINATION) MULT : 24.31646750351273
#
# ====> FITNESS = 706.0350308491186 <====
#
#
# ================================== MULT  TO  FAIS ==================================
#
#
# Distance of journey 2147.8105130574254 KM
# Eligible aircrafts:
#  ['Aircraft 1' 'Aircraft 27' 'Aircraft 37' 'Aircraft 47' 'Aircraft 48'
#  'Aircraft 57' 'Aircraft 81' 'Aircraft 90' 'Aircraft 114' 'Aircraft 123'
#  'Aircraft 159' 'Aircraft 160' 'Aircraft 203' 'Aircraft 208'
#  'Aircraft 210' 'Aircraft 229' 'Aircraft 299' 'Aircraft 323'
#  'Aircraft 339' 'Aircraft 343' 'Aircraft 383' 'Aircraft 397'
#  'Aircraft 406' 'Aircraft 425' 'Aircraft 454' 'Aircraft 455'
#  'Aircraft 461' 'Aircraft 474' 'Aircraft 488' 'Aircraft 502'
#  'Aircraft 574' 'Aircraft 632' 'Aircraft 634' 'Aircraft 644'
#  'Aircraft 656' 'Aircraft 678' 'Aircraft 685']
# 37 aircrafts available at airport  MULT
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 339  6709.734391         188.0                  132.573579
#
#   ICAO CODES
# 0       MULT
#
# Duration of flight: 11.424524005624603 Hrs
#
# Fuel consumption: 1514.5900355286167 Litres
#
# Wind speed in (SOURCE) MULT : 24.31646750351273
#
# Wind speed in (DESTINATION) FAIS : 9.469713183972084
#
# ====> FITNESS = 1753.685931298462 <====
#
#
# ================================== FAIS  TO  KARA ==================================
#
#
# Distance of journey 2062.907899058996 KM
# Eligible aircrafts:
#  ['Aircraft 38' 'Aircraft 43' 'Aircraft 61' 'Aircraft 85' 'Aircraft 87'
#  'Aircraft 94' 'Aircraft 97' 'Aircraft 136' 'Aircraft 148' 'Aircraft 153'
#  'Aircraft 180' 'Aircraft 187' 'Aircraft 204' 'Aircraft 209'
#  'Aircraft 227' 'Aircraft 256' 'Aircraft 270' 'Aircraft 281'
#  'Aircraft 303' 'Aircraft 304' 'Aircraft 326' 'Aircraft 348'
#  'Aircraft 356' 'Aircraft 372' 'Aircraft 374' 'Aircraft 382'
#  'Aircraft 391' 'Aircraft 434' 'Aircraft 438' 'Aircraft 466'
#  'Aircraft 469' 'Aircraft 471' 'Aircraft 481' 'Aircraft 485'
#  'Aircraft 487' 'Aircraft 497' 'Aircraft 506' 'Aircraft 522'
#  'Aircraft 554' 'Aircraft 562' 'Aircraft 567' 'Aircraft 585'
#  'Aircraft 595' 'Aircraft 596' 'Aircraft 599' 'Aircraft 600'
#  'Aircraft 627' 'Aircraft 638' 'Aircraft 652' 'Aircraft 659'
#  'Aircraft 676']
# 51 aircrafts available at airport  FAIS
#
#
# Best aircraft for journey :
#    Aircraft Type   Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 391  2561.84544    443.340978                  100.746911
#
#   ICAO CODES
# 0       FAIS
#
# Duration of flight: 4.653095478843078 Hrs
#
# Fuel consumption: 468.78499796934403 Litres
#
# Wind speed in (SOURCE) FAIS : 9.469713183972084
#
# Wind speed in (DESTINATION) KARA : 8.418232851835846
#
# ====> FITNESS = 467.7423629438332 <====
#
#
# ================================== ISLA  TO  RAWA ==================================
#
#
# Distance of journey 1535.642210933263 KM
# Eligible aircrafts:
#  ['Aircraft 14' 'Aircraft 35' 'Aircraft 62' 'Aircraft 69' 'Aircraft 95'
#  'Aircraft 120' 'Aircraft 127' 'Aircraft 138' 'Aircraft 143'
#  'Aircraft 195' 'Aircraft 223' 'Aircraft 234' 'Aircraft 258'
#  'Aircraft 262' 'Aircraft 264' 'Aircraft 284' 'Aircraft 287'
#  'Aircraft 313' 'Aircraft 344' 'Aircraft 346' 'Aircraft 365'
#  'Aircraft 395' 'Aircraft 400' 'Aircraft 410' 'Aircraft 412'
#  'Aircraft 421' 'Aircraft 462' 'Aircraft 468' 'Aircraft 470'
#  'Aircraft 479' 'Aircraft 503' 'Aircraft 505' 'Aircraft 507'
#  'Aircraft 511' 'Aircraft 513' 'Aircraft 514' 'Aircraft 516'
#  'Aircraft 517' 'Aircraft 520' 'Aircraft 530' 'Aircraft 532'
#  'Aircraft 565' 'Aircraft 568' 'Aircraft 572' 'Aircraft 584'
#  'Aircraft 601' 'Aircraft 606' 'Aircraft 610' 'Aircraft 635'
#  'Aircraft 640' 'Aircraft 654' 'Aircraft 658' 'Aircraft 667'
#  'Aircraft 686']
# 54 aircrafts available at airport  ISLA
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 344  4379.380871    480.757355                    103.3628
#
#   ICAO CODES
# 0       ISLA
#
# Duration of flight: 3.1942147023968657 Hrs
#
# Fuel consumption: 330.1629746418554 Litres
#
# Wind speed in (SOURCE) ISLA : 28.74836369922879
#
# Wind speed in (DESTINATION) RAWA : 5.084001221175267
#
# ====> FITNESS = 408.6756541515059 <====
#
#
# ================================== RAWA  TO  GWAD ==================================
#
#
# Distance of journey 1816.28191644359 KM
# Eligible aircrafts:
#  ['Aircraft 7' 'Aircraft 21' 'Aircraft 65' 'Aircraft 113' 'Aircraft 129'
#  'Aircraft 130' 'Aircraft 132' 'Aircraft 142' 'Aircraft 146'
#  'Aircraft 152' 'Aircraft 155' 'Aircraft 175' 'Aircraft 183'
#  'Aircraft 186' 'Aircraft 201' 'Aircraft 207' 'Aircraft 242'
#  'Aircraft 244' 'Aircraft 257' 'Aircraft 271' 'Aircraft 279'
#  'Aircraft 291' 'Aircraft 311' 'Aircraft 312' 'Aircraft 314'
#  'Aircraft 318' 'Aircraft 333' 'Aircraft 362' 'Aircraft 364'
#  'Aircraft 377' 'Aircraft 380' 'Aircraft 389' 'Aircraft 414'
#  'Aircraft 423' 'Aircraft 490' 'Aircraft 515' 'Aircraft 519'
#  'Aircraft 527' 'Aircraft 546' 'Aircraft 548' 'Aircraft 569'
#  'Aircraft 582' 'Aircraft 592' 'Aircraft 593' 'Aircraft 603'
#  'Aircraft 604' 'Aircraft 609' 'Aircraft 613' 'Aircraft 617'
#  'Aircraft 624' 'Aircraft 642' 'Aircraft 647' 'Aircraft 673'
#  'Aircraft 682' 'Aircraft 696' 'Aircraft 698']
# 56 aircrafts available at airport  RAWA
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 362  4473.545487         188.0                  203.101791
#
#   ICAO CODES
# 0       RAWA
#
# Duration of flight: 9.661074023636116 Hrs
#
# Fuel consumption: 1962.1814418783963 Litres
#
# Wind speed in (SOURCE) RAWA : 5.084001221175267
#
# Wind speed in (DESTINATION) GWAD : 18.95246078940032
#
# ====> FITNESS = 2079.199037529951 <====
#
#
# ================================== GWAD  TO  QUET ==================================
#
#
# Distance of journey 4283.120941556519 KM
# Eligible aircrafts:
#  ['Aircraft 10' 'Aircraft 40' 'Aircraft 53' 'Aircraft 92' 'Aircraft 124'
#  'Aircraft 139' 'Aircraft 163' 'Aircraft 169' 'Aircraft 188'
#  'Aircraft 216' 'Aircraft 233' 'Aircraft 282' 'Aircraft 302'
#  'Aircraft 331' 'Aircraft 351' 'Aircraft 373' 'Aircraft 390'
#  'Aircraft 413' 'Aircraft 472' 'Aircraft 494' 'Aircraft 498'
#  'Aircraft 528' 'Aircraft 534' 'Aircraft 535' 'Aircraft 564'
#  'Aircraft 586' 'Aircraft 615' 'Aircraft 645' 'Aircraft 650'
#  'Aircraft 664' 'Aircraft 674' 'Aircraft 680' 'Aircraft 699']
# 33 aircrafts available at airport  GWAD
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 413  7072.843801         188.0                   194.49954
#
#   ICAO CODES
# 0       GWAD
#
# Duration of flight: 22.78255819976872 Hrs
#
# Fuel consumption: 4431.1970961385405 Litres
#
# Wind speed in (SOURCE) GWAD : 18.95246078940032
#
# Wind speed in (DESTINATION) QUET : 8.16415203630792
#
# ====> FITNESS = 4731.64339161255 <====
#
#
# ================================== QUET  TO  SUKK ==================================
#
#
# Distance of journey 3905.949436436678 KM
# Eligible aircrafts:
#  ['Aircraft 8' 'Aircraft 9' 'Aircraft 42' 'Aircraft 64' 'Aircraft 79'
#  'Aircraft 101' 'Aircraft 166' 'Aircraft 170' 'Aircraft 205'
#  'Aircraft 225' 'Aircraft 226' 'Aircraft 239' 'Aircraft 253'
#  'Aircraft 261' 'Aircraft 274' 'Aircraft 275' 'Aircraft 292'
#  'Aircraft 341' 'Aircraft 342' 'Aircraft 371' 'Aircraft 394'
#  'Aircraft 428' 'Aircraft 449' 'Aircraft 459' 'Aircraft 478'
#  'Aircraft 496' 'Aircraft 529' 'Aircraft 555' 'Aircraft 611'
#  'Aircraft 651' 'Aircraft 663' 'Aircraft 691']
# 32 aircrafts available at airport  QUET
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 394  6530.110221    523.541709                  135.245908
#
#   ICAO CODES
# 0       QUET
#
# Duration of flight: 7.460627052397991 Hrs
#
# Fuel consumption: 1009.0192822337276 Litres
#
# Wind speed in (SOURCE) QUET : 8.16415203630792
#
# Wind speed in (DESTINATION) SUKK : 1.9345625731803675
#
# ====> FITNESS = 930.132309135549 <====
#
#
# ================================== SUKK  TO  MULT ==================================
#
#
# Distance of journey 2343.9635236069694 KM
# Eligible aircrafts:
#  ['Aircraft 5' 'Aircraft 11' 'Aircraft 13' 'Aircraft 49' 'Aircraft 51'
#  'Aircraft 107' 'Aircraft 144' 'Aircraft 220' 'Aircraft 230'
#  'Aircraft 235' 'Aircraft 236' 'Aircraft 265' 'Aircraft 272'
#  'Aircraft 295' 'Aircraft 296' 'Aircraft 298' 'Aircraft 332'
#  'Aircraft 360' 'Aircraft 366' 'Aircraft 402' 'Aircraft 430'
#  'Aircraft 439' 'Aircraft 442' 'Aircraft 448' 'Aircraft 452'
#  'Aircraft 486' 'Aircraft 493' 'Aircraft 510' 'Aircraft 543'
#  'Aircraft 570' 'Aircraft 580' 'Aircraft 588' 'Aircraft 605'
#  'Aircraft 649']
# 34 aircrafts available at airport  SUKK
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 439  4037.772098    423.339854                  205.712577
#
#   ICAO CODES
# 0       SUKK
#
# Duration of flight: 5.53683643049288 Hrs
#
# Fuel consumption: 1138.9968926677277 Litres
#
# Wind speed in (SOURCE) SUKK : 1.9345625731803675
#
# Wind speed in (DESTINATION) MULT : 24.31646750351273
#
# ====> FITNESS = 1204.2536472277445 <====
#
#
# ================================== MULT  TO  PESH ==================================
#
#
# Distance of journey 2738.2918032963544 KM
# Eligible aircrafts:
#  ['Aircraft 1' 'Aircraft 27' 'Aircraft 37' 'Aircraft 47' 'Aircraft 48'
#  'Aircraft 57' 'Aircraft 81' 'Aircraft 90' 'Aircraft 114' 'Aircraft 123'
#  'Aircraft 159' 'Aircraft 160' 'Aircraft 203' 'Aircraft 208'
#  'Aircraft 210' 'Aircraft 229' 'Aircraft 323' 'Aircraft 339'
#  'Aircraft 383' 'Aircraft 397' 'Aircraft 425' 'Aircraft 454'
#  'Aircraft 474' 'Aircraft 488' 'Aircraft 502' 'Aircraft 574'
#  'Aircraft 632' 'Aircraft 634' 'Aircraft 644' 'Aircraft 656'
#  'Aircraft 678' 'Aircraft 685']
# 32 aircrafts available at airport  MULT
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 339  6709.734391         188.0                  132.573579
#
#   ICAO CODES
# 0       MULT
#
# Duration of flight: 14.565381932427417 Hrs
#
# Fuel consumption: 1930.984811941582 Litres
#
# Wind speed in (SOURCE) MULT : 24.31646750351273
#
# Wind speed in (DESTINATION) PESH : 29.840278142668957
#
# ====> FITNESS = 2794.76691614364 <====
#
#
# ================================== PESH  TO  GUJR ==================================
#
#
# Distance of journey 4539.824886490667 KM
# Eligible aircrafts:
#  ['Aircraft 3' 'Aircraft 29' 'Aircraft 71' 'Aircraft 102' 'Aircraft 106'
#  'Aircraft 158' 'Aircraft 168' 'Aircraft 189' 'Aircraft 199'
#  'Aircraft 231' 'Aircraft 250' 'Aircraft 263' 'Aircraft 300'
#  'Aircraft 317' 'Aircraft 324' 'Aircraft 392' 'Aircraft 401'
#  'Aircraft 404' 'Aircraft 544' 'Aircraft 547' 'Aircraft 579'
#  'Aircraft 590' 'Aircraft 623' 'Aircraft 657']
# 24 aircrafts available at airport  PESH
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 401  6383.227777    518.715999                  240.072488
#
#   ICAO CODES
# 0       PESH
#
# Duration of flight: 8.752043306932077 Hrs
#
# Fuel consumption: 2101.124809855085 Litres
#
# Wind speed in (SOURCE) PESH : 29.840278142668957
#
# Wind speed in (DESTINATION) GUJR : 27.1881540287728
#
# ====> FITNESS = 2708.3572907914404 <====
#
#
# ================================== GUJR  TO  KARA ==================================
#
#
# Distance of journey 3854.664706560092 KM
# Eligible aircrafts:
#  ['Aircraft 6' 'Aircraft 23' 'Aircraft 33' 'Aircraft 36' 'Aircraft 44'
#  'Aircraft 59' 'Aircraft 80' 'Aircraft 91' 'Aircraft 96' 'Aircraft 116'
#  'Aircraft 117' 'Aircraft 125' 'Aircraft 133' 'Aircraft 135'
#  'Aircraft 140' 'Aircraft 174' 'Aircraft 191' 'Aircraft 194'
#  'Aircraft 211' 'Aircraft 237' 'Aircraft 259' 'Aircraft 267'
#  'Aircraft 268' 'Aircraft 269' 'Aircraft 276' 'Aircraft 308'
#  'Aircraft 385' 'Aircraft 411' 'Aircraft 417' 'Aircraft 433'
#  'Aircraft 450' 'Aircraft 475' 'Aircraft 545' 'Aircraft 573'
#  'Aircraft 575' 'Aircraft 629' 'Aircraft 646']
# 37 aircrafts available at airport  GUJR
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0    Aircraft 6  4335.214703    409.685328                  117.576422
#
#   ICAO CODES
# 0       GUJR
#
# Duration of flight: 9.4088424639909 Hrs
#
# Fuel consumption: 1106.258034466997 Litres
#
# Wind speed in (SOURCE) GUJR : 27.1881540287728
#
# Wind speed in (DESTINATION) KARA : 8.418232851835846
#
# ====> FITNESS = 1320.8073725582813 <====
#
#
# ================================== ISLA  TO  QUET ==================================
#
#
# Distance of journey 2618.1466727439088 KM
# Eligible aircrafts:
#  ['Aircraft 14' 'Aircraft 35' 'Aircraft 62' 'Aircraft 69' 'Aircraft 95'
#  'Aircraft 120' 'Aircraft 127' 'Aircraft 138' 'Aircraft 143'
#  'Aircraft 195' 'Aircraft 223' 'Aircraft 234' 'Aircraft 258'
#  'Aircraft 262' 'Aircraft 264' 'Aircraft 284' 'Aircraft 287'
#  'Aircraft 344' 'Aircraft 346' 'Aircraft 365' 'Aircraft 395'
#  'Aircraft 400' 'Aircraft 410' 'Aircraft 412' 'Aircraft 421'
#  'Aircraft 462' 'Aircraft 468' 'Aircraft 470' 'Aircraft 503'
#  'Aircraft 505' 'Aircraft 507' 'Aircraft 511' 'Aircraft 513'
#  'Aircraft 516' 'Aircraft 517' 'Aircraft 520' 'Aircraft 530'
#  'Aircraft 532' 'Aircraft 565' 'Aircraft 584' 'Aircraft 601'
#  'Aircraft 606' 'Aircraft 610' 'Aircraft 640' 'Aircraft 654'
#  'Aircraft 667']
# 46 aircrafts available at airport  ISLA
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 344  4379.380871    480.757355                    103.3628
#
#   ICAO CODES
# 0       ISLA
#
# Duration of flight: 5.4458796037050785 Hrs
#
# Fuel consumption: 562.9013629395289 Litres
#
# Wind speed in (SOURCE) ISLA : 28.74836369922879
#
# Wind speed in (DESTINATION) QUET : 8.16415203630792
#
# ====> FITNESS = 696.7591777110282 <====
#
#
# ================================== QUET  TO  MULT ==================================
#
#
# Distance of journey 807.9319278256058 KM
# Eligible aircrafts:
#  ['Aircraft 8' 'Aircraft 9' 'Aircraft 31' 'Aircraft 39' 'Aircraft 42'
#  'Aircraft 52' 'Aircraft 56' 'Aircraft 64' 'Aircraft 66' 'Aircraft 76'
#  'Aircraft 79' 'Aircraft 101' 'Aircraft 131' 'Aircraft 147' 'Aircraft 166'
#  'Aircraft 170' 'Aircraft 176' 'Aircraft 205' 'Aircraft 219'
#  'Aircraft 225' 'Aircraft 226' 'Aircraft 232' 'Aircraft 239'
#  'Aircraft 249' 'Aircraft 252' 'Aircraft 253' 'Aircraft 260'
#  'Aircraft 261' 'Aircraft 273' 'Aircraft 274' 'Aircraft 275'
#  'Aircraft 285' 'Aircraft 292' 'Aircraft 330' 'Aircraft 341'
#  'Aircraft 342' 'Aircraft 371' 'Aircraft 387' 'Aircraft 394'
#  'Aircraft 415' 'Aircraft 428' 'Aircraft 435' 'Aircraft 436'
#  'Aircraft 449' 'Aircraft 457' 'Aircraft 459' 'Aircraft 473'
#  'Aircraft 477' 'Aircraft 478' 'Aircraft 480' 'Aircraft 496'
#  'Aircraft 523' 'Aircraft 529' 'Aircraft 531' 'Aircraft 536'
#  'Aircraft 539' 'Aircraft 552' 'Aircraft 555' 'Aircraft 556'
#  'Aircraft 607' 'Aircraft 611' 'Aircraft 619' 'Aircraft 630'
#  'Aircraft 643' 'Aircraft 651' 'Aircraft 663' 'Aircraft 688'
#  'Aircraft 689' 'Aircraft 691']
# 69 aircrafts available at airport  QUET
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 285  2497.589124         188.0                  110.397294
#
#   ICAO CODES
# 0       QUET
#
# Duration of flight: 4.29751025439152 Hrs
#
# Fuel consumption: 474.43350210756944 Litres
#
# Wind speed in (SOURCE) QUET : 8.16415203630792
#
# Wind speed in (DESTINATION) MULT : 24.31646750351273
#
# ====> FITNESS = 576.2859488838052 <====
#
#
# ================================== MULT  TO  FAIS ==================================
#
#
# Distance of journey 2147.8105130574254 KM
# Eligible aircrafts:
#  ['Aircraft 1' 'Aircraft 27' 'Aircraft 37' 'Aircraft 47' 'Aircraft 48'
#  'Aircraft 57' 'Aircraft 81' 'Aircraft 90' 'Aircraft 114' 'Aircraft 123'
#  'Aircraft 159' 'Aircraft 160' 'Aircraft 203' 'Aircraft 208'
#  'Aircraft 210' 'Aircraft 229' 'Aircraft 299' 'Aircraft 323'
#  'Aircraft 339' 'Aircraft 343' 'Aircraft 383' 'Aircraft 397'
#  'Aircraft 406' 'Aircraft 425' 'Aircraft 454' 'Aircraft 455'
#  'Aircraft 461' 'Aircraft 474' 'Aircraft 488' 'Aircraft 502'
#  'Aircraft 574' 'Aircraft 632' 'Aircraft 634' 'Aircraft 644'
#  'Aircraft 656' 'Aircraft 678' 'Aircraft 685']
# 37 aircrafts available at airport  MULT
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 339  6709.734391         188.0                  132.573579
#
#   ICAO CODES
# 0       MULT
#
# Duration of flight: 11.424524005624603 Hrs
#
# Fuel consumption: 1514.5900355286167 Litres
#
# Wind speed in (SOURCE) MULT : 24.31646750351273
#
# Wind speed in (DESTINATION) FAIS : 9.469713183972084
#
# ====> FITNESS = 1753.685931298462 <====
#
#
# ================================== FAIS  TO  LAHO ==================================
#
#
# Distance of journey 3350.492501110844 KM
# Eligible aircrafts:
#  ['Aircraft 85' 'Aircraft 136' 'Aircraft 153' 'Aircraft 180' 'Aircraft 187'
#  'Aircraft 209' 'Aircraft 227' 'Aircraft 256' 'Aircraft 281'
#  'Aircraft 303' 'Aircraft 304' 'Aircraft 326' 'Aircraft 348'
#  'Aircraft 356' 'Aircraft 372' 'Aircraft 374' 'Aircraft 434'
#  'Aircraft 438' 'Aircraft 466' 'Aircraft 469' 'Aircraft 481'
#  'Aircraft 487' 'Aircraft 497' 'Aircraft 506' 'Aircraft 554'
#  'Aircraft 562' 'Aircraft 567' 'Aircraft 585' 'Aircraft 595'
#  'Aircraft 600' 'Aircraft 627' 'Aircraft 638' 'Aircraft 652'
#  'Aircraft 676']
# 34 aircrafts available at airport  FAIS
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 638  4849.841421    469.239493                  101.104975
#
#   ICAO CODES
# 0       FAIS
#
# Duration of flight: 7.140261100080441 Hrs
#
# Fuel consumption: 721.9159215829219 Litres
#
# Wind speed in (SOURCE) FAIS : 9.469713183972084
#
# Wind speed in (DESTINATION) LAHO : nan
#
# ====> FITNESS = 719.5489781104585 <====
#
#
# ================================== LAHO  TO  PESH ==================================
#
#
# Distance of journey 649.2888417337849 KM
# Eligible aircrafts:
#  ['Aircraft 24' 'Aircraft 26' 'Aircraft 58' 'Aircraft 63' 'Aircraft 67'
#  'Aircraft 75' 'Aircraft 86' 'Aircraft 89' 'Aircraft 93' 'Aircraft 98'
#  'Aircraft 100' 'Aircraft 109' 'Aircraft 115' 'Aircraft 121'
#  'Aircraft 151' 'Aircraft 161' 'Aircraft 182' 'Aircraft 185'
#  'Aircraft 193' 'Aircraft 212' 'Aircraft 214' 'Aircraft 241'
#  'Aircraft 283' 'Aircraft 288' 'Aircraft 306' 'Aircraft 315'
#  'Aircraft 319' 'Aircraft 320' 'Aircraft 338' 'Aircraft 340'
#  'Aircraft 403' 'Aircraft 416' 'Aircraft 424' 'Aircraft 427'
#  'Aircraft 429' 'Aircraft 432' 'Aircraft 447' 'Aircraft 463'
#  'Aircraft 504' 'Aircraft 518' 'Aircraft 542' 'Aircraft 549'
#  'Aircraft 550' 'Aircraft 597' 'Aircraft 612' 'Aircraft 621'
#  'Aircraft 626' 'Aircraft 631' 'Aircraft 641' 'Aircraft 669'
#  'Aircraft 672' 'Aircraft 677' 'Aircraft 683' 'Aircraft 690']
# 54 aircrafts available at airport  LAHO
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 182  4009.067327     365.63442                  126.075662
#
#   ICAO CODES
# 0       LAHO
#
# Duration of flight: 1.7757869801917845 Hrs
#
# Fuel consumption: 223.88351995085588 Litres
#
# Wind speed in (SOURCE) LAHO : nan
#
# Wind speed in (DESTINATION) PESH : 29.840278142668957
#
# ====> FITNESS = 262.49009171419084 <====
#
#
# ================================== PESH  TO  KARA ==================================
#
#
# Distance of journey 2394.175641008821 KM
# Eligible aircrafts:
#  ['Aircraft 3' 'Aircraft 29' 'Aircraft 71' 'Aircraft 88' 'Aircraft 102'
#  'Aircraft 106' 'Aircraft 158' 'Aircraft 168' 'Aircraft 189'
#  'Aircraft 199' 'Aircraft 215' 'Aircraft 224' 'Aircraft 231'
#  'Aircraft 250' 'Aircraft 254' 'Aircraft 263' 'Aircraft 300'
#  'Aircraft 317' 'Aircraft 324' 'Aircraft 328' 'Aircraft 392'
#  'Aircraft 401' 'Aircraft 404' 'Aircraft 405' 'Aircraft 419'
#  'Aircraft 444' 'Aircraft 508' 'Aircraft 512' 'Aircraft 544'
#  'Aircraft 547' 'Aircraft 579' 'Aircraft 590' 'Aircraft 623'
#  'Aircraft 633' 'Aircraft 657' 'Aircraft 694']
# 36 aircrafts available at airport  PESH
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0   Aircraft 88  2695.777256    460.672986                  176.202779
#
#   ICAO CODES
# 0       PESH
#
# Duration of flight: 5.197126196496422 Hrs
#
# Fuel consumption: 915.7480797282701 Litres
#
# Wind speed in (SOURCE) PESH : 29.840278142668957
#
# Wind speed in (DESTINATION) KARA : 8.418232851835846
#
# ====> FITNESS = 996.171802130852 <====
#
#
# ================================== ISLA  TO  GUJR ==================================
#
#
# Distance of journey 355.99578649191903 KM
# Eligible aircrafts:
#  ['Aircraft 14' 'Aircraft 35' 'Aircraft 62' 'Aircraft 69' 'Aircraft 95'
#  'Aircraft 120' 'Aircraft 127' 'Aircraft 138' 'Aircraft 143'
#  'Aircraft 195' 'Aircraft 223' 'Aircraft 234' 'Aircraft 245'
#  'Aircraft 258' 'Aircraft 262' 'Aircraft 264' 'Aircraft 284'
#  'Aircraft 287' 'Aircraft 313' 'Aircraft 344' 'Aircraft 346'
#  'Aircraft 365' 'Aircraft 395' 'Aircraft 400' 'Aircraft 410'
#  'Aircraft 412' 'Aircraft 421' 'Aircraft 462' 'Aircraft 468'
#  'Aircraft 470' 'Aircraft 479' 'Aircraft 503' 'Aircraft 505'
#  'Aircraft 507' 'Aircraft 511' 'Aircraft 513' 'Aircraft 514'
#  'Aircraft 516' 'Aircraft 517' 'Aircraft 520' 'Aircraft 530'
#  'Aircraft 532' 'Aircraft 565' 'Aircraft 568' 'Aircraft 572'
#  'Aircraft 584' 'Aircraft 601' 'Aircraft 606' 'Aircraft 610'
#  'Aircraft 618' 'Aircraft 635' 'Aircraft 640' 'Aircraft 654'
#  'Aircraft 658' 'Aircraft 667' 'Aircraft 686']
# 56 aircrafts available at airport  ISLA
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 344  4379.380871    480.757355                    103.3628
#
#   ICAO CODES
# 0       ISLA
#
# Duration of flight: 0.7404895275135422 Hrs
#
# Fuel consumption: 76.53907074923902 Litres
#
# Wind speed in (SOURCE) ISLA : 28.74836369922879
#
# Wind speed in (DESTINATION) GUJR : 27.1881540287728
#
# ====> FITNESS = 118.42505523417745 <====
#
#
# ================================== GUJR  TO  GWAD ==================================
#
#
# Distance of journey 2891.0565542721574 KM
# Eligible aircrafts:
#  ['Aircraft 6' 'Aircraft 23' 'Aircraft 33' 'Aircraft 36' 'Aircraft 44'
#  'Aircraft 59' 'Aircraft 80' 'Aircraft 91' 'Aircraft 96' 'Aircraft 116'
#  'Aircraft 117' 'Aircraft 125' 'Aircraft 133' 'Aircraft 135'
#  'Aircraft 140' 'Aircraft 172' 'Aircraft 174' 'Aircraft 191'
#  'Aircraft 194' 'Aircraft 202' 'Aircraft 211' 'Aircraft 237'
#  'Aircraft 259' 'Aircraft 267' 'Aircraft 268' 'Aircraft 269'
#  'Aircraft 276' 'Aircraft 293' 'Aircraft 308' 'Aircraft 350'
#  'Aircraft 368' 'Aircraft 381' 'Aircraft 385' 'Aircraft 411'
#  'Aircraft 417' 'Aircraft 433' 'Aircraft 450' 'Aircraft 475'
#  'Aircraft 524' 'Aircraft 526' 'Aircraft 545' 'Aircraft 558'
#  'Aircraft 571' 'Aircraft 573' 'Aircraft 575' 'Aircraft 578'
#  'Aircraft 629' 'Aircraft 646' 'Aircraft 655' 'Aircraft 666'
#  'Aircraft 681']
# 51 aircrafts available at airport  GUJR
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0    Aircraft 6  4335.214703    409.685328                  117.576422
#
#   ICAO CODES
# 0       GUJR
#
# Duration of flight: 7.056773479504457 Hrs
#
# Fuel consumption: 829.7101783766226 Litres
#
# Wind speed in (SOURCE) GUJR : 27.1881540287728
#
# Wind speed in (DESTINATION) GWAD : 18.95246078940032
#
# ====> FITNESS = 1238.2817644512024 <====
#
#
# ================================== GWAD  TO  MULT ==================================
#
#
# Distance of journey 1943.988940297758 KM
# Eligible aircrafts:
#  ['Aircraft 10' 'Aircraft 25' 'Aircraft 40' 'Aircraft 45' 'Aircraft 53'
#  'Aircraft 55' 'Aircraft 92' 'Aircraft 119' 'Aircraft 124' 'Aircraft 139'
#  'Aircraft 162' 'Aircraft 163' 'Aircraft 169' 'Aircraft 188'
#  'Aircraft 216' 'Aircraft 233' 'Aircraft 240' 'Aircraft 282'
#  'Aircraft 297' 'Aircraft 302' 'Aircraft 316' 'Aircraft 331'
#  'Aircraft 351' 'Aircraft 373' 'Aircraft 384' 'Aircraft 390'
#  'Aircraft 409' 'Aircraft 413' 'Aircraft 472' 'Aircraft 483'
#  'Aircraft 494' 'Aircraft 498' 'Aircraft 528' 'Aircraft 534'
#  'Aircraft 535' 'Aircraft 564' 'Aircraft 586' 'Aircraft 614'
#  'Aircraft 615' 'Aircraft 622' 'Aircraft 628' 'Aircraft 645'
#  'Aircraft 650' 'Aircraft 664' 'Aircraft 668' 'Aircraft 674'
#  'Aircraft 680' 'Aircraft 687' 'Aircraft 699']
# 49 aircrafts available at airport  GWAD
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 384  3669.018443    535.323871                  134.901614
#
#   ICAO CODES
# 0       GWAD
#
# Duration of flight: 3.631425841401726 Hrs
#
# Fuel consumption: 489.88520643054886 Litres
#
# Wind speed in (SOURCE) GWAD : 18.95246078940032
#
# Wind speed in (DESTINATION) MULT : 24.31646750351273
#
# ====> FITNESS = 706.0350308491186 <====
#
#
# ================================== MULT  TO  PESH ==================================
#
#
# Distance of journey 2738.2918032963544 KM
# Eligible aircrafts:
#  ['Aircraft 1' 'Aircraft 27' 'Aircraft 37' 'Aircraft 47' 'Aircraft 48'
#  'Aircraft 57' 'Aircraft 81' 'Aircraft 90' 'Aircraft 114' 'Aircraft 123'
#  'Aircraft 159' 'Aircraft 160' 'Aircraft 203' 'Aircraft 208'
#  'Aircraft 210' 'Aircraft 229' 'Aircraft 323' 'Aircraft 339'
#  'Aircraft 383' 'Aircraft 397' 'Aircraft 425' 'Aircraft 454'
#  'Aircraft 474' 'Aircraft 488' 'Aircraft 502' 'Aircraft 574'
#  'Aircraft 632' 'Aircraft 634' 'Aircraft 644' 'Aircraft 656'
#  'Aircraft 678' 'Aircraft 685']
# 32 aircrafts available at airport  MULT
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 339  6709.734391         188.0                  132.573579
#
#   ICAO CODES
# 0       MULT
#
# Duration of flight: 14.565381932427417 Hrs
#
# Fuel consumption: 1930.984811941582 Litres
#
# Wind speed in (SOURCE) MULT : 24.31646750351273
#
# Wind speed in (DESTINATION) PESH : 29.840278142668957
#
# ====> FITNESS = 2794.76691614364 <====
#
#
# ================================== PESH  TO  LAHO ==================================
#
#
# Distance of journey 4327.574031718002 KM
# Eligible aircrafts:
#  ['Aircraft 3' 'Aircraft 29' 'Aircraft 71' 'Aircraft 102' 'Aircraft 106'
#  'Aircraft 158' 'Aircraft 168' 'Aircraft 189' 'Aircraft 199'
#  'Aircraft 231' 'Aircraft 250' 'Aircraft 263' 'Aircraft 300'
#  'Aircraft 317' 'Aircraft 324' 'Aircraft 392' 'Aircraft 401'
#  'Aircraft 404' 'Aircraft 544' 'Aircraft 547' 'Aircraft 579'
#  'Aircraft 590' 'Aircraft 623' 'Aircraft 657']
# 24 aircrafts available at airport  PESH
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 401  6383.227777    518.715999                  240.072488
#
#   ICAO CODES
# 0       PESH
#
# Duration of flight: 8.342858212936152 Hrs
#
# Fuel consumption: 2002.8907263769154 Litres
#
# Wind speed in (SOURCE) PESH : 29.840278142668957
#
# Wind speed in (DESTINATION) LAHO : nan
#
# ====> FITNESS = 2581.7332107061334 <====
#
#
# ================================== LAHO  TO  RAWA ==================================
#
#
# Distance of journey 3519.2324447242754 KM
# Eligible aircrafts:
#  ['Aircraft 58' 'Aircraft 63' 'Aircraft 67' 'Aircraft 75' 'Aircraft 89'
#  'Aircraft 93' 'Aircraft 98' 'Aircraft 100' 'Aircraft 115' 'Aircraft 151'
#  'Aircraft 161' 'Aircraft 182' 'Aircraft 193' 'Aircraft 214'
#  'Aircraft 241' 'Aircraft 283' 'Aircraft 338' 'Aircraft 403'
#  'Aircraft 416' 'Aircraft 427' 'Aircraft 429' 'Aircraft 432'
#  'Aircraft 447' 'Aircraft 463' 'Aircraft 550' 'Aircraft 597'
#  'Aircraft 612' 'Aircraft 621' 'Aircraft 631' 'Aircraft 641'
#  'Aircraft 669' 'Aircraft 672' 'Aircraft 683' 'Aircraft 690']
# 34 aircrafts available at airport  LAHO
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 182  4009.067327     365.63442                  126.075662
#
#   ICAO CODES
# 0       LAHO
#
# Duration of flight: 9.625003163341274 Hrs
#
# Fuel consumption: 1213.4786501893605 Litres
#
# Wind speed in (SOURCE) LAHO : nan
#
# Wind speed in (DESTINATION) RAWA : 5.084001221175267
#
# ====> FITNESS = 1422.731437540988 <====
#
#
# ================================== RAWA  TO  SUKK ==================================
#
#
# Distance of journey 2870.365307761366 KM
# Eligible aircrafts:
#  ['Aircraft 7' 'Aircraft 21' 'Aircraft 65' 'Aircraft 113' 'Aircraft 129'
#  'Aircraft 130' 'Aircraft 132' 'Aircraft 142' 'Aircraft 146'
#  'Aircraft 152' 'Aircraft 155' 'Aircraft 175' 'Aircraft 183'
#  'Aircraft 186' 'Aircraft 201' 'Aircraft 207' 'Aircraft 242'
#  'Aircraft 244' 'Aircraft 257' 'Aircraft 271' 'Aircraft 279'
#  'Aircraft 291' 'Aircraft 311' 'Aircraft 312' 'Aircraft 314'
#  'Aircraft 318' 'Aircraft 333' 'Aircraft 362' 'Aircraft 364'
#  'Aircraft 377' 'Aircraft 389' 'Aircraft 414' 'Aircraft 423'
#  'Aircraft 515' 'Aircraft 519' 'Aircraft 527' 'Aircraft 569'
#  'Aircraft 582' 'Aircraft 592' 'Aircraft 593' 'Aircraft 603'
#  'Aircraft 604' 'Aircraft 613' 'Aircraft 617' 'Aircraft 624'
#  'Aircraft 642' 'Aircraft 647' 'Aircraft 682' 'Aircraft 696'
#  'Aircraft 698']
# 50 aircrafts available at airport  RAWA
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 362  4473.545487         188.0                  203.101791
#
#   ICAO CODES
# 0       RAWA
#
# Duration of flight: 15.267900573198753 Hrs
#
# Fuel consumption: 3100.93795864528 Litres
#
# Wind speed in (SOURCE) RAWA : 5.084001221175267
#
# Wind speed in (DESTINATION) SUKK : 1.9345625731803675
#
# ====> FITNESS = 2628.6935882476587 <====
#
#
# ================================== SUKK  TO  QUET ==================================
#
#
# Distance of journey 3932.472504671838 KM
# Eligible aircrafts:
#  ['Aircraft 5' 'Aircraft 11' 'Aircraft 51' 'Aircraft 107' 'Aircraft 144'
#  'Aircraft 220' 'Aircraft 230' 'Aircraft 236' 'Aircraft 265'
#  'Aircraft 272' 'Aircraft 295' 'Aircraft 296' 'Aircraft 298'
#  'Aircraft 332' 'Aircraft 360' 'Aircraft 366' 'Aircraft 402'
#  'Aircraft 430' 'Aircraft 439' 'Aircraft 452' 'Aircraft 486'
#  'Aircraft 493' 'Aircraft 510' 'Aircraft 543' 'Aircraft 580'
#  'Aircraft 588' 'Aircraft 605' 'Aircraft 649']
# 28 aircrafts available at airport  SUKK
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 439  4037.772098    423.339854                  205.712577
#
#   ICAO CODES
# 0       SUKK
#
# Duration of flight: 9.289162056699965 Hrs
#
# Fuel consumption: 1910.8974684170644 Litres
#
# Wind speed in (SOURCE) SUKK : 1.9345625731803675
#
# Wind speed in (DESTINATION) QUET : 8.16415203630792
#
# ====> FITNESS = 1616.303089592944 <====
#
#
# ================================== QUET  TO  FAIS ==================================
#
#
# Distance of journey 2141.7854701159963 KM
# Eligible aircrafts:
#  ['Aircraft 8' 'Aircraft 9' 'Aircraft 39' 'Aircraft 42' 'Aircraft 52'
#  'Aircraft 56' 'Aircraft 64' 'Aircraft 66' 'Aircraft 79' 'Aircraft 101'
#  'Aircraft 131' 'Aircraft 147' 'Aircraft 166' 'Aircraft 170'
#  'Aircraft 205' 'Aircraft 219' 'Aircraft 225' 'Aircraft 226'
#  'Aircraft 232' 'Aircraft 239' 'Aircraft 252' 'Aircraft 253'
#  'Aircraft 260' 'Aircraft 261' 'Aircraft 274' 'Aircraft 275'
#  'Aircraft 285' 'Aircraft 292' 'Aircraft 341' 'Aircraft 342'
#  'Aircraft 371' 'Aircraft 387' 'Aircraft 394' 'Aircraft 428'
#  'Aircraft 449' 'Aircraft 457' 'Aircraft 459' 'Aircraft 477'
#  'Aircraft 478' 'Aircraft 480' 'Aircraft 496' 'Aircraft 523'
#  'Aircraft 529' 'Aircraft 552' 'Aircraft 555' 'Aircraft 556'
#  'Aircraft 611' 'Aircraft 619' 'Aircraft 630' 'Aircraft 651'
#  'Aircraft 663' 'Aircraft 691']
# 52 aircrafts available at airport  QUET
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 285  2497.589124         188.0                  110.397294
#
#   ICAO CODES
# 0       QUET
#
# Duration of flight: 11.39247590487232 Hrs
#
# Fuel consumption: 1257.6985094337977 Litres
#
# Wind speed in (SOURCE) QUET : 8.16415203630792
#
# Wind speed in (DESTINATION) FAIS : 9.469713183972084
#
# ====> FITNESS = 1222.163233749828 <====
#
#
# ================================== FAIS  TO  SIAL ==================================
#
#
# Distance of journey 3642.19123605557 KM
# Eligible aircrafts:
#  ['Aircraft 85' 'Aircraft 136' 'Aircraft 153' 'Aircraft 180' 'Aircraft 187'
#  'Aircraft 209' 'Aircraft 227' 'Aircraft 256' 'Aircraft 281'
#  'Aircraft 303' 'Aircraft 326' 'Aircraft 348' 'Aircraft 356'
#  'Aircraft 372' 'Aircraft 374' 'Aircraft 434' 'Aircraft 438'
#  'Aircraft 466' 'Aircraft 469' 'Aircraft 481' 'Aircraft 487'
#  'Aircraft 497' 'Aircraft 506' 'Aircraft 554' 'Aircraft 562'
#  'Aircraft 567' 'Aircraft 585' 'Aircraft 595' 'Aircraft 600'
#  'Aircraft 627' 'Aircraft 638' 'Aircraft 652' 'Aircraft 676']
# 33 aircrafts available at airport  FAIS
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 638  4849.841421    469.239493                  101.104975
#
#   ICAO CODES
# 0       FAIS
#
# Duration of flight: 7.761902583945262 Hrs
#
# Fuel consumption: 784.7669684043598 Litres
#
# Wind speed in (SOURCE) FAIS : 9.469713183972084
#
# Wind speed in (DESTINATION) SIAL : 1.9451271194031197
#
# ====> FITNESS = 782.1939554014097 <====
#
#
# ================================== SIAL  TO  KARA ==================================
#
#
# Distance of journey 2846.3495920213313 KM
# Eligible aircrafts:
#  ['Aircraft 46' 'Aircraft 78' 'Aircraft 84' 'Aircraft 103' 'Aircraft 108'
#  'Aircraft 118' 'Aircraft 128' 'Aircraft 149' 'Aircraft 171'
#  'Aircraft 198' 'Aircraft 200' 'Aircraft 213' 'Aircraft 218'
#  'Aircraft 222' 'Aircraft 238' 'Aircraft 243' 'Aircraft 255'
#  'Aircraft 290' 'Aircraft 335' 'Aircraft 336' 'Aircraft 358'
#  'Aircraft 359' 'Aircraft 363' 'Aircraft 426' 'Aircraft 440'
#  'Aircraft 453' 'Aircraft 460' 'Aircraft 464' 'Aircraft 476'
#  'Aircraft 492' 'Aircraft 499' 'Aircraft 509' 'Aircraft 521'
#  'Aircraft 563' 'Aircraft 576' 'Aircraft 583' 'Aircraft 602'
#  'Aircraft 608' 'Aircraft 662' 'Aircraft 665' 'Aircraft 671'
#  'Aircraft 684' 'Aircraft 692' 'Aircraft 693']
# 44 aircrafts available at airport  SIAL
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 290  3003.136295         188.0                  102.117357
#
#   ICAO CODES
# 0       SIAL
#
# Duration of flight: 15.140157404368784 Hrs
#
# Fuel consumption: 1546.0728557966438 Litres
#
# Wind speed in (SOURCE) SIAL : 1.9451271194031197
#
# Wind speed in (DESTINATION) KARA : 8.418232851835846
#
# ====> FITNESS = 1536.455721188714 <====
#
#
# ================================== ISLA  TO  RAWA ==================================
#
#
# Distance of journey 1535.642210933263 KM
# Eligible aircrafts:
#  ['Aircraft 14' 'Aircraft 35' 'Aircraft 62' 'Aircraft 69' 'Aircraft 95'
#  'Aircraft 120' 'Aircraft 127' 'Aircraft 138' 'Aircraft 143'
#  'Aircraft 195' 'Aircraft 223' 'Aircraft 234' 'Aircraft 258'
#  'Aircraft 262' 'Aircraft 264' 'Aircraft 284' 'Aircraft 287'
#  'Aircraft 313' 'Aircraft 344' 'Aircraft 346' 'Aircraft 365'
#  'Aircraft 395' 'Aircraft 400' 'Aircraft 410' 'Aircraft 412'
#  'Aircraft 421' 'Aircraft 462' 'Aircraft 468' 'Aircraft 470'
#  'Aircraft 479' 'Aircraft 503' 'Aircraft 505' 'Aircraft 507'
#  'Aircraft 511' 'Aircraft 513' 'Aircraft 514' 'Aircraft 516'
#  'Aircraft 517' 'Aircraft 520' 'Aircraft 530' 'Aircraft 532'
#  'Aircraft 565' 'Aircraft 568' 'Aircraft 572' 'Aircraft 584'
#  'Aircraft 601' 'Aircraft 606' 'Aircraft 610' 'Aircraft 635'
#  'Aircraft 640' 'Aircraft 654' 'Aircraft 658' 'Aircraft 667'
#  'Aircraft 686']
# 54 aircrafts available at airport  ISLA
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 344  4379.380871    480.757355                    103.3628
#
#   ICAO CODES
# 0       ISLA
#
# Duration of flight: 3.1942147023968657 Hrs
#
# Fuel consumption: 330.1629746418554 Litres
#
# Wind speed in (SOURCE) ISLA : 28.74836369922879
#
# Wind speed in (DESTINATION) RAWA : 5.084001221175267
#
# ====> FITNESS = 408.6756541515059 <====
#
#
# ================================== RAWA  TO  SIAL ==================================
#
#
# Distance of journey 3629.3374050920092 KM
# Eligible aircrafts:
#  ['Aircraft 7' 'Aircraft 21' 'Aircraft 65' 'Aircraft 113' 'Aircraft 129'
#  'Aircraft 130' 'Aircraft 132' 'Aircraft 142' 'Aircraft 146'
#  'Aircraft 152' 'Aircraft 175' 'Aircraft 186' 'Aircraft 201'
#  'Aircraft 207' 'Aircraft 242' 'Aircraft 244' 'Aircraft 257'
#  'Aircraft 271' 'Aircraft 311' 'Aircraft 312' 'Aircraft 314'
#  'Aircraft 318' 'Aircraft 333' 'Aircraft 362' 'Aircraft 364'
#  'Aircraft 389' 'Aircraft 414' 'Aircraft 423' 'Aircraft 515'
#  'Aircraft 519' 'Aircraft 527' 'Aircraft 569' 'Aircraft 582'
#  'Aircraft 592' 'Aircraft 593' 'Aircraft 603' 'Aircraft 604'
#  'Aircraft 613' 'Aircraft 617' 'Aircraft 624' 'Aircraft 642'
#  'Aircraft 647' 'Aircraft 682' 'Aircraft 696']
# 44 aircrafts available at airport  RAWA
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 362  4473.545487         188.0                  203.101791
#
#   ICAO CODES
# 0       RAWA
#
# Duration of flight: 19.30498619729792 Hrs
#
# Fuel consumption: 3920.877281281798 Litres
#
# Wind speed in (SOURCE) RAWA : 5.084001221175267
#
# Wind speed in (DESTINATION) SIAL : 1.9451271194031197
#
# ====> FITNESS = 3323.763682816196 <====
#
#
# ================================== SIAL  TO  QUET ==================================
#
#
# Distance of journey 1986.158352196521 KM
# Eligible aircrafts:
#  ['Aircraft 46' 'Aircraft 60' 'Aircraft 78' 'Aircraft 84' 'Aircraft 103'
#  'Aircraft 108' 'Aircraft 118' 'Aircraft 128' 'Aircraft 149'
#  'Aircraft 171' 'Aircraft 198' 'Aircraft 200' 'Aircraft 213'
#  'Aircraft 217' 'Aircraft 218' 'Aircraft 222' 'Aircraft 238'
#  'Aircraft 243' 'Aircraft 255' 'Aircraft 290' 'Aircraft 327'
#  'Aircraft 335' 'Aircraft 336' 'Aircraft 358' 'Aircraft 359'
#  'Aircraft 363' 'Aircraft 398' 'Aircraft 426' 'Aircraft 431'
#  'Aircraft 440' 'Aircraft 453' 'Aircraft 460' 'Aircraft 464'
#  'Aircraft 476' 'Aircraft 492' 'Aircraft 499' 'Aircraft 509'
#  'Aircraft 521' 'Aircraft 563' 'Aircraft 576' 'Aircraft 583'
#  'Aircraft 602' 'Aircraft 608' 'Aircraft 637' 'Aircraft 662'
#  'Aircraft 665' 'Aircraft 671' 'Aircraft 684' 'Aircraft 692'
#  'Aircraft 693' 'Aircraft 697']
# 51 aircrafts available at airport  SIAL
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 290  3003.136295         188.0                  102.117357
#
#   ICAO CODES
# 0       SIAL
#
# Duration of flight: 10.564672086151708 Hrs
#
# Fuel consumption: 1078.836388984863 Litres
#
# Wind speed in (SOURCE) SIAL : 1.9451271194031197
#
# Wind speed in (DESTINATION) QUET : 8.16415203630792
#
# ====> FITNESS = 1072.1256348739555 <====
#
#
# ================================== QUET  TO  SUKK ==================================
#
#
# Distance of journey 3905.949436436678 KM
# Eligible aircrafts:
#  ['Aircraft 8' 'Aircraft 9' 'Aircraft 42' 'Aircraft 64' 'Aircraft 79'
#  'Aircraft 101' 'Aircraft 166' 'Aircraft 170' 'Aircraft 205'
#  'Aircraft 225' 'Aircraft 226' 'Aircraft 239' 'Aircraft 253'
#  'Aircraft 261' 'Aircraft 274' 'Aircraft 275' 'Aircraft 292'
#  'Aircraft 341' 'Aircraft 342' 'Aircraft 371' 'Aircraft 394'
#  'Aircraft 428' 'Aircraft 449' 'Aircraft 459' 'Aircraft 478'
#  'Aircraft 496' 'Aircraft 529' 'Aircraft 555' 'Aircraft 611'
#  'Aircraft 651' 'Aircraft 663' 'Aircraft 691']
# 32 aircrafts available at airport  QUET
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 394  6530.110221    523.541709                  135.245908
#
#   ICAO CODES
# 0       QUET
#
# Duration of flight: 7.460627052397991 Hrs
#
# Fuel consumption: 1009.0192822337276 Litres
#
# Wind speed in (SOURCE) QUET : 8.16415203630792
#
# Wind speed in (DESTINATION) SUKK : 1.9345625731803675
#
# ====> FITNESS = 930.132309135549 <====
#
#
# ================================== SUKK  TO  MULT ==================================
#
#
# Distance of journey 2343.9635236069694 KM
# Eligible aircrafts:
#  ['Aircraft 5' 'Aircraft 11' 'Aircraft 13' 'Aircraft 49' 'Aircraft 51'
#  'Aircraft 107' 'Aircraft 144' 'Aircraft 220' 'Aircraft 230'
#  'Aircraft 235' 'Aircraft 236' 'Aircraft 265' 'Aircraft 272'
# ...
#  'Aircraft 423' 'Aircraft 490' 'Aircraft 515' 'Aircraft 519'
#  'Aircraft 527' 'Aircraft 546' 'Aircraft 548' 'Aircraft 569'
#  'Aircraft 582' 'Aircraft 592' 'Aircraft 593' 'Aircraft 603'
#  'Aircraft 604' 'Aircraft 609' 'Aircraft 613' 'Aircraft 617'
#  'Aircraft 624' 'Aircraft 642' 'Aircraft 647' 'Aircraft 682'
#  'Aircraft 696' 'Aircraft 698']
# 55 aircrafts available at airport  RAWA
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 362  4473.545487         188.0                  203.101791
#
#   ICAO CODES
# 0       RAWA
#
# Duration of flight: 9.821208953821419 Hrs
#
# Fuel consumption: 1994.705133078501 Litres
#
# Wind speed in (SOURCE) RAWA : 5.084001221175267
#
# Wind speed in (DESTINATION) MULT : 24.31646750351273
#
# ====> FITNESS = 2113.6623272119914 <====
#
#
# ================================== MULT  TO  LAHO ==================================
#
#
# Distance of journey 3913.100560936302 KM
# Eligible aircrafts:
#  ['Aircraft 27' 'Aircraft 37' 'Aircraft 47' 'Aircraft 48' 'Aircraft 57'
#  'Aircraft 81' 'Aircraft 90' 'Aircraft 114' 'Aircraft 123' 'Aircraft 160'
#  'Aircraft 203' 'Aircraft 208' 'Aircraft 210' 'Aircraft 229'
#  'Aircraft 323' 'Aircraft 339' 'Aircraft 397' 'Aircraft 454'
#  'Aircraft 474' 'Aircraft 488' 'Aircraft 574' 'Aircraft 632'
#  'Aircraft 634' 'Aircraft 644' 'Aircraft 656' 'Aircraft 678'
#  'Aircraft 685']
# 27 aircrafts available at airport  MULT
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 339  6709.734391         188.0                  132.573579
#
#   ICAO CODES
# 0       MULT
#
# Duration of flight: 20.814364685831393 Hrs
#
# Fuel consumption: 2759.434820522783 Litres
#
# Wind speed in (SOURCE) MULT : 24.31646750351273
#
# Wind speed in (DESTINATION) LAHO : nan
#
# ====> FITNESS = 3993.80517959514 <====
#
#
# ================================== LAHO  TO  GUJR ==================================
#
#
# Distance of journey 4769.101068335625 KM
# Eligible aircrafts:
#  ['Aircraft 58' 'Aircraft 63' 'Aircraft 67' 'Aircraft 93' 'Aircraft 98'
#  'Aircraft 100' 'Aircraft 115' 'Aircraft 151' 'Aircraft 161'
#  'Aircraft 193' 'Aircraft 241' 'Aircraft 283' 'Aircraft 403'
#  'Aircraft 416' 'Aircraft 429' 'Aircraft 432' 'Aircraft 463'
#  'Aircraft 550' 'Aircraft 641' 'Aircraft 669' 'Aircraft 683'
#  'Aircraft 690']
# 22 aircrafts available at airport  LAHO
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 151  7251.917489    309.235465                   127.61702
#
#   ICAO CODES
# 0       LAHO
#
# Duration of flight: 15.422231950852016 Hrs
#
# Fuel consumption: 1968.1392796784644 Litres
#
# Wind speed in (SOURCE) LAHO : nan
#
# Wind speed in (DESTINATION) GUJR : 27.1881540287728
#
# ====> FITNESS = 2875.569459844509 <====
#
#
# ================================== GUJR  TO  FAIS ==================================
#
#
# Distance of journey 4950.192016477745 KM
# Eligible aircrafts:
#  ['Aircraft 33' 'Aircraft 36' 'Aircraft 44' 'Aircraft 59' 'Aircraft 80'
#  'Aircraft 91' 'Aircraft 96' 'Aircraft 117' 'Aircraft 125' 'Aircraft 133'
#  'Aircraft 135' 'Aircraft 174' 'Aircraft 191' 'Aircraft 194'
#  'Aircraft 211' 'Aircraft 237' 'Aircraft 259' 'Aircraft 267'
#  'Aircraft 268' 'Aircraft 276' 'Aircraft 308' 'Aircraft 411'
#  'Aircraft 417' 'Aircraft 450' 'Aircraft 545' 'Aircraft 575'
#  'Aircraft 629' 'Aircraft 646']
# 28 aircrafts available at airport  GUJR
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 237  5782.094167         188.0                  132.019319
#
#   ICAO CODES
# 0       GUJR
#
# Duration of flight: 26.330808598285877 Hrs
#
# Fuel consumption: 3476.1754244738704 Litres
#
# Wind speed in (SOURCE) GUJR : 27.1881540287728
#
# Wind speed in (DESTINATION) FAIS : 9.469713183972084
#
# ====> FITNESS = 4029.058818850357 <====
#
#
# ================================== FAIS  TO  KARA ==================================
#
#
# Distance of journey 2062.907899058996 KM
# Eligible aircrafts:
#  ['Aircraft 38' 'Aircraft 43' 'Aircraft 61' 'Aircraft 85' 'Aircraft 87'
#  'Aircraft 94' 'Aircraft 97' 'Aircraft 136' 'Aircraft 148' 'Aircraft 153'
#  'Aircraft 180' 'Aircraft 187' 'Aircraft 204' 'Aircraft 209'
#  'Aircraft 227' 'Aircraft 256' 'Aircraft 270' 'Aircraft 281'
#  'Aircraft 303' 'Aircraft 304' 'Aircraft 326' 'Aircraft 348'
#  'Aircraft 356' 'Aircraft 372' 'Aircraft 374' 'Aircraft 382'
#  'Aircraft 391' 'Aircraft 434' 'Aircraft 438' 'Aircraft 466'
#  'Aircraft 469' 'Aircraft 471' 'Aircraft 481' 'Aircraft 485'
#  'Aircraft 487' 'Aircraft 497' 'Aircraft 506' 'Aircraft 522'
#  'Aircraft 554' 'Aircraft 562' 'Aircraft 567' 'Aircraft 585'
#  'Aircraft 595' 'Aircraft 596' 'Aircraft 599' 'Aircraft 600'
#  'Aircraft 627' 'Aircraft 638' 'Aircraft 652' 'Aircraft 659'
#  'Aircraft 676']
# 51 aircrafts available at airport  FAIS
#
#
# Best aircraft for journey :
#    Aircraft Type   Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 391  2561.84544    443.340978                  100.746911
#
#   ICAO CODES
# 0       FAIS
#
# Duration of flight: 4.653095478843078 Hrs
#
# Fuel consumption: 468.78499796934403 Litres
#
# Wind speed in (SOURCE) FAIS : 9.469713183972084
#
# Wind speed in (DESTINATION) KARA : 8.418232851835846
#
# ====> FITNESS = 467.7423629438332 <====
#
#
# ================================== ISLA  TO  QUET ==================================
#
#
# Distance of journey 2618.1466727439088 KM
# Eligible aircrafts:
#  ['Aircraft 14' 'Aircraft 35' 'Aircraft 62' 'Aircraft 69' 'Aircraft 95'
#  'Aircraft 120' 'Aircraft 127' 'Aircraft 138' 'Aircraft 143'
#  'Aircraft 195' 'Aircraft 223' 'Aircraft 234' 'Aircraft 258'
#  'Aircraft 262' 'Aircraft 264' 'Aircraft 284' 'Aircraft 287'
#  'Aircraft 344' 'Aircraft 346' 'Aircraft 365' 'Aircraft 395'
#  'Aircraft 400' 'Aircraft 410' 'Aircraft 412' 'Aircraft 421'
#  'Aircraft 462' 'Aircraft 468' 'Aircraft 470' 'Aircraft 503'
#  'Aircraft 505' 'Aircraft 507' 'Aircraft 511' 'Aircraft 513'
#  'Aircraft 516' 'Aircraft 517' 'Aircraft 520' 'Aircraft 530'
#  'Aircraft 532' 'Aircraft 565' 'Aircraft 584' 'Aircraft 601'
#  'Aircraft 606' 'Aircraft 610' 'Aircraft 640' 'Aircraft 654'
#  'Aircraft 667']
# 46 aircrafts available at airport  ISLA
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 344  4379.380871    480.757355                    103.3628
#
#   ICAO CODES
# 0       ISLA
#
# Duration of flight: 5.4458796037050785 Hrs
#
# Fuel consumption: 562.9013629395289 Litres
#
# Wind speed in (SOURCE) ISLA : 28.74836369922879
#
# Wind speed in (DESTINATION) QUET : 8.16415203630792
#
# ====> FITNESS = 696.7591777110282 <====
#
#
# ================================== QUET  TO  GUJR ==================================
#
#
# Distance of journey 872.534813059055 KM
# Eligible aircrafts:
#  ['Aircraft 8' 'Aircraft 9' 'Aircraft 31' 'Aircraft 39' 'Aircraft 42'
#  'Aircraft 52' 'Aircraft 56' 'Aircraft 64' 'Aircraft 66' 'Aircraft 76'
#  'Aircraft 79' 'Aircraft 101' 'Aircraft 131' 'Aircraft 147' 'Aircraft 166'
#  'Aircraft 170' 'Aircraft 176' 'Aircraft 205' 'Aircraft 219'
#  'Aircraft 225' 'Aircraft 226' 'Aircraft 232' 'Aircraft 239'
#  'Aircraft 249' 'Aircraft 252' 'Aircraft 253' 'Aircraft 260'
#  'Aircraft 261' 'Aircraft 273' 'Aircraft 274' 'Aircraft 275'
#  'Aircraft 285' 'Aircraft 292' 'Aircraft 330' 'Aircraft 341'
#  'Aircraft 342' 'Aircraft 371' 'Aircraft 387' 'Aircraft 394'
#  'Aircraft 415' 'Aircraft 428' 'Aircraft 435' 'Aircraft 436'
#  'Aircraft 449' 'Aircraft 457' 'Aircraft 459' 'Aircraft 473'
#  'Aircraft 477' 'Aircraft 478' 'Aircraft 480' 'Aircraft 496'
#  'Aircraft 523' 'Aircraft 529' 'Aircraft 531' 'Aircraft 539'
#  'Aircraft 552' 'Aircraft 555' 'Aircraft 556' 'Aircraft 607'
#  'Aircraft 611' 'Aircraft 619' 'Aircraft 630' 'Aircraft 643'
#  'Aircraft 651' 'Aircraft 663' 'Aircraft 688' 'Aircraft 689'
#  'Aircraft 691']
# 68 aircrafts available at airport  QUET
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 285  2497.589124         188.0                  110.397294
#
#   ICAO CODES
# 0       QUET
#
# Duration of flight: 4.641142622654548 Hrs
#
# Fuel consumption: 512.3695856214945 Litres
#
# Wind speed in (SOURCE) QUET : 8.16415203630792
#
# Wind speed in (DESTINATION) GUJR : 27.1881540287728
#
# ====> FITNESS = 622.3662357683531 <====
#
#
# ================================== GUJR  TO  KARA ==================================
#
#
# Distance of journey 3854.664706560092 KM
# Eligible aircrafts:
#  ['Aircraft 6' 'Aircraft 23' 'Aircraft 33' 'Aircraft 36' 'Aircraft 44'
#  'Aircraft 59' 'Aircraft 80' 'Aircraft 91' 'Aircraft 96' 'Aircraft 116'
#  'Aircraft 117' 'Aircraft 125' 'Aircraft 133' 'Aircraft 135'
#  'Aircraft 140' 'Aircraft 174' 'Aircraft 191' 'Aircraft 194'
#  'Aircraft 211' 'Aircraft 237' 'Aircraft 259' 'Aircraft 267'
#  'Aircraft 268' 'Aircraft 269' 'Aircraft 276' 'Aircraft 308'
#  'Aircraft 385' 'Aircraft 411' 'Aircraft 417' 'Aircraft 433'
#  'Aircraft 450' 'Aircraft 475' 'Aircraft 545' 'Aircraft 573'
#  'Aircraft 575' 'Aircraft 629' 'Aircraft 646']
# 37 aircrafts available at airport  GUJR
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0    Aircraft 6  4335.214703    409.685328                  117.576422
#
#   ICAO CODES
# 0       GUJR
#
# Duration of flight: 9.4088424639909 Hrs
#
# Fuel consumption: 1106.258034466997 Litres
#
# Wind speed in (SOURCE) GUJR : 27.1881540287728
#
# Wind speed in (DESTINATION) KARA : 8.418232851835846
#
# ====> FITNESS = 1320.8073725582813 <====
#
#
# ================================== ISLA  TO  SUKK ==================================
#
#
# Distance of journey 2041.204056433359 KM
# Eligible aircrafts:
#  ['Aircraft 14' 'Aircraft 35' 'Aircraft 62' 'Aircraft 69' 'Aircraft 95'
#  'Aircraft 120' 'Aircraft 127' 'Aircraft 138' 'Aircraft 143'
#  'Aircraft 195' 'Aircraft 223' 'Aircraft 234' 'Aircraft 258'
#  'Aircraft 262' 'Aircraft 264' 'Aircraft 284' 'Aircraft 287'
#  'Aircraft 313' 'Aircraft 344' 'Aircraft 346' 'Aircraft 365'
#  'Aircraft 395' 'Aircraft 400' 'Aircraft 410' 'Aircraft 412'
#  'Aircraft 421' 'Aircraft 462' 'Aircraft 468' 'Aircraft 470'
#  'Aircraft 503' 'Aircraft 505' 'Aircraft 507' 'Aircraft 511'
#  'Aircraft 513' 'Aircraft 514' 'Aircraft 516' 'Aircraft 517'
#  'Aircraft 520' 'Aircraft 530' 'Aircraft 532' 'Aircraft 565'
#  'Aircraft 584' 'Aircraft 601' 'Aircraft 606' 'Aircraft 610'
#  'Aircraft 640' 'Aircraft 654' 'Aircraft 667']
# 48 aircrafts available at airport  ISLA
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 344  4379.380871    480.757355                    103.3628
#
#   ICAO CODES
# 0       ISLA
#
# Duration of flight: 4.2458093175812746 Hrs
#
# Fuel consumption: 438.85873826917594 Litres
#
# Wind speed in (SOURCE) ISLA : 28.74836369922879
#
# Wind speed in (DESTINATION) SUKK : 1.9345625731803675
#
# ====> FITNESS = 543.2192453948267 <====
#
#
# ================================== SUKK  TO  FAIS ==================================
#
#
# Distance of journey 1440.1888765019678 KM
# Eligible aircrafts:
#  ['Aircraft 5' 'Aircraft 11' 'Aircraft 13' 'Aircraft 18' 'Aircraft 49'
#  'Aircraft 51' 'Aircraft 107' 'Aircraft 144' 'Aircraft 220' 'Aircraft 230'
#  'Aircraft 235' 'Aircraft 236' 'Aircraft 265' 'Aircraft 272'
#  'Aircraft 295' 'Aircraft 296' 'Aircraft 298' 'Aircraft 332'
#  'Aircraft 360' 'Aircraft 366' 'Aircraft 367' 'Aircraft 402'
#  'Aircraft 407' 'Aircraft 430' 'Aircraft 439' 'Aircraft 442'
#  'Aircraft 448' 'Aircraft 452' 'Aircraft 456' 'Aircraft 486'
#  'Aircraft 493' 'Aircraft 495' 'Aircraft 510' 'Aircraft 537'
#  'Aircraft 543' 'Aircraft 570' 'Aircraft 580' 'Aircraft 588'
#  'Aircraft 605' 'Aircraft 616' 'Aircraft 649']
# 41 aircrafts available at airport  SUKK
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 439  4037.772098    423.339854                  205.712577
#
#   ICAO CODES
# 0       SUKK
#
# Duration of flight: 3.4019685707121883 Hrs
#
# Fuel consumption: 699.8277228589761 Litres
#
# Wind speed in (SOURCE) SUKK : 1.9345625731803675
#
# Wind speed in (DESTINATION) FAIS : 9.469713183972084
#
# ====> FITNESS = 591.938463122649 <====
#
#
# ================================== FAIS  TO  SIAL ==================================
#
#
# Distance of journey 3642.19123605557 KM
# Eligible aircrafts:
#  ['Aircraft 85' 'Aircraft 136' 'Aircraft 153' 'Aircraft 180' 'Aircraft 187'
#  'Aircraft 209' 'Aircraft 227' 'Aircraft 256' 'Aircraft 281'
#  'Aircraft 303' 'Aircraft 326' 'Aircraft 348' 'Aircraft 356'
#  'Aircraft 372' 'Aircraft 374' 'Aircraft 434' 'Aircraft 438'
#  'Aircraft 466' 'Aircraft 469' 'Aircraft 481' 'Aircraft 487'
#  'Aircraft 497' 'Aircraft 506' 'Aircraft 554' 'Aircraft 562'
#  'Aircraft 567' 'Aircraft 585' 'Aircraft 595' 'Aircraft 600'
#  'Aircraft 627' 'Aircraft 638' 'Aircraft 652' 'Aircraft 676']
# 33 aircrafts available at airport  FAIS
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 638  4849.841421    469.239493                  101.104975
#
#   ICAO CODES
# 0       FAIS
#
# Duration of flight: 7.761902583945262 Hrs
#
# Fuel consumption: 784.7669684043598 Litres
#
# Wind speed in (SOURCE) FAIS : 9.469713183972084
#
# Wind speed in (DESTINATION) SIAL : 1.9451271194031197
#
# ====> FITNESS = 782.1939554014097 <====
#
#
# ================================== SIAL  TO  RAWA ==================================
#
#
# Distance of journey 3634.1119960727683 KM
# Eligible aircrafts:
#  ['Aircraft 78' 'Aircraft 84' 'Aircraft 103' 'Aircraft 118' 'Aircraft 128'
#  'Aircraft 149' 'Aircraft 171' 'Aircraft 198' 'Aircraft 200'
#  'Aircraft 218' 'Aircraft 222' 'Aircraft 238' 'Aircraft 243'
#  'Aircraft 255' 'Aircraft 335' 'Aircraft 336' 'Aircraft 358'
#  'Aircraft 359' 'Aircraft 363' 'Aircraft 440' 'Aircraft 453'
#  'Aircraft 460' 'Aircraft 464' 'Aircraft 476' 'Aircraft 499'
#  'Aircraft 509' 'Aircraft 521' 'Aircraft 563' 'Aircraft 576'
#  'Aircraft 583' 'Aircraft 602' 'Aircraft 608' 'Aircraft 671'
#  'Aircraft 692' 'Aircraft 693']
# 35 aircrafts available at airport  SIAL
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 335  6997.835414    367.522587                  167.937615
#
#   ICAO CODES
# 0       SIAL
#
# Duration of flight: 9.888132379443796 Hrs
#
# Fuel consumption: 1660.5893645488584 Litres
#
# Wind speed in (SOURCE) SIAL : 1.9451271194031197
#
# Wind speed in (DESTINATION) RAWA : 5.084001221175267
#
# ====> FITNESS = 1459.0565265675145 <====
#
#
# ================================== RAWA  TO  KARA ==================================
#
#
# Distance of journey 3116.167517961767 KM
# Eligible aircrafts:
#  ['Aircraft 7' 'Aircraft 21' 'Aircraft 65' 'Aircraft 113' 'Aircraft 129'
#  'Aircraft 130' 'Aircraft 132' 'Aircraft 142' 'Aircraft 146'
#  'Aircraft 152' 'Aircraft 155' 'Aircraft 175' 'Aircraft 186'
#  'Aircraft 201' 'Aircraft 207' 'Aircraft 242' 'Aircraft 244'
#  'Aircraft 257' 'Aircraft 271' 'Aircraft 279' 'Aircraft 311'
#  'Aircraft 312' 'Aircraft 314' 'Aircraft 318' 'Aircraft 333'
#  'Aircraft 362' 'Aircraft 364' 'Aircraft 389' 'Aircraft 414'
#  'Aircraft 423' 'Aircraft 515' 'Aircraft 519' 'Aircraft 527'
#  'Aircraft 569' 'Aircraft 582' 'Aircraft 592' 'Aircraft 593'
#  'Aircraft 603' 'Aircraft 604' 'Aircraft 613' 'Aircraft 617'
#  'Aircraft 624' 'Aircraft 642' 'Aircraft 647' 'Aircraft 682'
#  'Aircraft 696' 'Aircraft 698']
# 47 aircrafts available at airport  RAWA
#
#
# Best aircraft for journey :
#    Aircraft Type    Max Range  Cruise Speed  Fuel Consumption at Cruise  \
# 0  Aircraft 362  4473.545487         188.0                  203.101791
#
#   ICAO CODES
# 0       RAWA
#
# Duration of flight: 16.575359138094505 Hrs
#
# Fuel consumption: 3366.4851354691928 Litres
# 127.0.0.1 - - [06/Dec/2023 14:30:41] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Dec/2023 14:30:41] "
# Wind speed in (SOURCE) RAWA : 5.084001221175267
#
# Wind speed in (DESTINATION) KARA : 8.418232851835846
#
# ====> FITNESS = 2853.80036897127 <====
# [['ISLA', 'MULT', 'KARA'], ['ISLA', 'MULT', 'KARA']]
# [['ISLA', 'KARA', 'KARA'], ['ISLA', 'MULT', 'KARA']]
# Generation 1, Best Fitness: 2639.9327860376625
# GET /static/peakpx.jpg HTTP/1.1" 304 -
